# %%
import pandas as pd

# %%
df=pd.read_csv('metro-bike-share-trips-2020-q1.csv')
df.head()
# Out:
#      trip_id  duration     start_time       end_time  start_station  \
# 0  134867493        25  1/1/2020 0:16  1/1/2020 0:41           3063
# 1  134867799        35  1/1/2020 0:24  1/1/2020 0:59           4285
# 2  134868104        37  1/1/2020 0:31  1/1/2020 1:08           4344
# 3  134868103        36  1/1/2020 0:32  1/1/2020 1:08           4344
# 4  134868102        35  1/1/2020 0:33  1/1/2020 1:08           4344
#
#    start_lat   start_lon  end_station    end_lat     end_lon  bike_id  \
# 0  34.048038 -118.253738         4491  34.047440 -118.247940    18419
# 1        NaN         NaN         4354  34.017681 -118.409081    15661
# 2  34.014309 -118.491341         4322  34.005871 -118.429161    15848
# 3  34.014309 -118.491341         4322  34.005871 -118.429161    16053
# 4  34.014309 -118.491341         4322  34.005871 -118.429161    15694
#
#    plan_duration trip_route_category passholder_type bike_type
# 0             30             One Way    Monthly Pass  electric
# ...

# %%
len(df)
# Out:
# 76391

# %%
df2=pd.read_csv('applemobilitytrends-2020-06-08.csv')
df2.head()
# Out:
#          geo_type     region transportation_type alternative_name sub-region  \
# 0  country/region    Albania             driving              NaN        NaN
# 1  country/region    Albania             walking              NaN        NaN
# 2  country/region  Argentina             driving              NaN        NaN
# 3  country/region  Argentina             walking              NaN        NaN
# 4  country/region  Australia             driving               AU        NaN
#
#   country  2020-01-13  2020-01-14  2020-01-15  2020-01-16  ...  2020-05-30  \
# 0     NaN       100.0       95.30      101.43       97.20  ...       67.47
# 1     NaN       100.0      100.68       98.93       98.46  ...       56.67
# 2     NaN       100.0       97.07      102.45      111.21  ...       40.39
# 3     NaN       100.0       95.11      101.37      112.67  ...       28.70
# 4     NaN       100.0      102.98      104.21      108.63  ...       73.04
#
# ...

# %%
df2[df2[]]
# Out:
#      geo_type                  region transportation_type alternative_name  \
# 1556   county          Alameda County             driving              NaN
# 1573   county           Amador County             driving              NaN
# 1759   county            Butte County             driving              NaN
# 1767   county        Calaveras County             driving              NaN
# 1955   county           Colusa County             driving              NaN
# 1960   county     Contra Costa County             driving              NaN
# 2049   county        Del Norte County             driving              NaN
# 2113   county        El Dorado County             driving              NaN
# 2203   county           Fresno County             driving              NaN
# 2242   county            Glenn County             driving              NaN
# 2414   county         Humboldt County             driving              NaN
# ...

# %%
df_LA = df2[df2.region == 'Los Angeles']

# %%
df_LA.to_csv('apple_LA.csv',index=False)

# %%
pd.read_csv('apple_LA.csv')
# Out:
#   geo_type       region transportation_type alternative_name  sub-region  \
# 0     city  Los Angeles             driving               LA  California
# 1     city  Los Angeles             transit               LA  California
# 2     city  Los Angeles             walking               LA  California
#
#          country  2020-01-13  2020-01-14  2020-01-15  2020-01-16  ...  \
# 0  United States       100.0      105.93      112.23      111.73  ...
# 1  United States       100.0      103.78      105.28      103.12  ...
# 2  United States       100.0      105.72      111.35      111.68  ...
#
#    2020-05-30  2020-05-31  2020-06-01  2020-06-02  2020-06-03  2020-06-04  \
# 0       92.40       69.13       73.83       76.42       83.99       86.08
# 1       35.84       28.49       33.16       34.25       35.87       36.29
# 2      106.83       76.64       74.77       81.45       89.11       87.37
#
#    2020-06-05  2020-06-06  2020-06-07  2020-06-08
# ...

# %%
df['date'] = pd.to_datetime(df.start_time)

# %%
def extract_day(row):
    row['date'] = row['date'].date()
    return row

# %%
df = df.apply(extract_day, axis=1)

# %%
bike_trips_by_day = df.groupby('date').count().trip_id

# %%
bike_trips_by_day.plot()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df3=pd.read_csv('datasets_44181_819765_open-data-website-traffic.csv')
df3.head()
# Out:
#                       Date  Socrata Users  Socrata Sessions  \
# 0  2018-09-11T00:00:00.000            347               390
# 1  2018-09-10T00:00:00.000            609               682
# 2  2018-09-09T00:00:00.000            264               284
# 3  2018-09-08T00:00:00.000            251               282
# 4  2018-09-07T00:00:00.000            558               630
#
#    Socrata Bounce Rate  Geohub Users  Geohub Sessions  Geohub Bounce Rate  \
# 0              24.1026           1.0              1.0               100.0
# 1              29.3255           1.0              1.0               100.0
# 2              30.6338           3.0              4.0                75.0
# 3              28.0142           2.0              2.0                50.0
# 4              26.3492           2.0              2.0               100.0
#
#    Combined Users
# 0           348.0
# 1           610.0
# 2           267.0
# 3           253.0
# 4           560.0

# %%
import json
with open('ridership_data.json','r') as fp:
    ridership_dict=json.load(fp)

# %%
ridership_dict
# Out:
# {'All': ['2019/05 908,385 566,541 420,264',
#   '2019/06 863,846 561,706 440,234',
#   '2019/07 872,973 569,918 450,159',
#   '2019/08 901,631 589,067 466,998',
#   '2019/09 954,583 572,003 453,841',
#   '2019/10 952,506 586,085 453,447',
#   '2019/11 854,195 542,270 393,086',
#   '2019/12 790,360 526,372 375,302',
#   '2020/01 816,652 523,739 385,277',
#   '2020/02 871,496 541,895 407,118',
#   '2020/03 563,759 353,523 301,403',
#   '2020/04 269,382 218,858 161,636',
#   '2020/05 323,231 265,291 217,501'],
#  '2': ['2019/05 12,129 7,878 5,790',
#   '2019/06 11,857 8,206 7,049',
#   '2019/07 11,667 7,897 6,078',
#   '2019/08 11,921 8,347 6,829',
#   '2019/09 12,511 8,161 6,650',
#   '2019/10 13,100 8,114 6,543',
#   '2019/11 11,710 7,888 5,844',
#   '2019/12 10,737 7,359 5,405',
#   '2020/01 11,344 7,363 5,499',
#   '2020/02 12,194 7,926 6,044',
#   '2020/03 7,304 4,948 4,022',
#   '2020/04 3,108 2,700 2,054',
#   '2020/05 3,617 3,260 2,795'],
#  '4': ['2019/05 14,632 12,453 9,695',
# ...

# %%
ridership_dict2={key:value for key, value in ridership_dict.items() if len(value)>0}

# %%
len(ridership_dict2)
# Out:
# 145

# %% [markdown]
# We will keep the weekday data only

# %%
ridership_dict2['150'][4].split(' ')
# Out:
# ['2019/09', '8,847', '8,224', '6,548']

# %%
ridership_dict3={}

# %%
for key, value in ridership_dict2.items():
    
    ridership_dict3[key] = [ item.split(' ')[1] for item in value]

# %%
ridership_dict3={key : [ item.split(' ')[1] for item in value] for key, value in ridership_dict2.items()}

# %%
columns = [ item.split(' ')[0] for item in ridership_dict['All']]

columns
# Out:
# ['2019/05',
#  '2019/06',
#  '2019/07',
#  '2019/08',
#  '2019/09',
#  '2019/10',
#  '2019/11',
#  '2019/12',
#  '2020/01',
#  '2020/02',
#  '2020/03',
#  '2020/04',
#  '2020/05']

# %%
ridership_dict4={key : value for key, value in ridership_dict3.items() if len(value) == 13}

# %%
ridership_dict4
# Out:
# {'All': ['908,385',
#   '863,846',
#   '872,973',
#   '901,631',
#   '954,583',
#   '952,506',
#   '854,195',
#   '790,360',
#   '816,652',
#   '871,496',
#   '563,759',
#   '269,382',
#   '323,231'],
#  '2': ['12,129',
#   '11,857',
#   '11,667',
#   '11,921',
#   '12,511',
#   '13,100',
#   '11,710',
#   '10,737',
#   '11,344',
#   '12,194',
#   '7,304',
#   '3,108',
#   '3,617'],
#  '4': ['14,632',
#   '14,545',
#   '14,467',
#   '14,899',
#   '15,619',
#   '15,595',
#   '14,569',
#   '13,798',
#   '14,039',
#   '15,192',
#   '9,725',
#   '5,033',
#   '6,449'],
#  '10': ['12,094',
#   '11,182',
#   '10,450',
#   '11,417',
#   '12,771',
#   '12,887',
#   '11,227',
#   '10,161',
#   '10,528',
#   '11,664',
#   '6,887',
#   '2,561',
#   '2,937'],
#  '14': ['17,387',
#   '16,908',
#   '15,700',
#   '16,782',
#   '18,301',
#   '18,429',
#   '16,588',
#   '15,028',
#   '15,630',
#   '16,904',
#   '10,398',
#   '4,059',
#   '4,613'],
#  '16': ['21,653',
#   '21,219',
#   '19,831',
# ...

# %%
len(ridership_dict4)
# Out:
# 135

# %%
import pandas as pd

# %%
ridership_df = pd.DataFrame.from_dict(ridership_dict4, orient='index', columns=columns)

# %%
ridership_df
# Out:
#      2019/05  2019/06  2019/07  2019/08  2019/09  2019/10  2019/11  2019/12  \
# All  908,385  863,846  872,973  901,631  954,583  952,506  854,195  790,360
# 2     12,129   11,857   11,667   11,921   12,511   13,100   11,710   10,737
# 4     14,632   14,545   14,467   14,899   15,619   15,595   14,569   13,798
# 10    12,094   11,182   10,450   11,417   12,771   12,887   11,227   10,161
# 14    17,387   16,908   15,700   16,782   18,301   18,429   16,588   15,028
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 780    7,502    7,312    6,319    6,454    7,109    6,976    6,596    6,075
# 788    1,902    1,809    1,832    1,899    2,065    2,103    1,937    1,766
# 794    3,916    3,846    3,673    3,861    3,976    4,121    3,854    3,491
# 901   22,836   20,651   19,834   20,483   23,229   23,356   21,690   19,179
# 910   16,269   16,015   16,806   18,310   21,267   22,347   19,203   16,451
#
#      2020/01  2020/02  2020/03  2020/04  2020/05
# ...

# %%
ridership_df.to_csv('bus_ridership.csv')

# %%
pd.read_csv('bus_ridership.csv', index_col=0)
# Out:
#      2019/05  2019/06  2019/07  2019/08  2019/09  2019/10  2019/11  2019/12  \
# All  908,385  863,846  872,973  901,631  954,583  952,506  854,195  790,360
# 2     12,129   11,857   11,667   11,921   12,511   13,100   11,710   10,737
# 4     14,632   14,545   14,467   14,899   15,619   15,595   14,569   13,798
# 10    12,094   11,182   10,450   11,417   12,771   12,887   11,227   10,161
# 14    17,387   16,908   15,700   16,782   18,301   18,429   16,588   15,028
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 780    7,502    7,312    6,319    6,454    7,109    6,976    6,596    6,075
# 788    1,902    1,809    1,832    1,899    2,065    2,103    1,937    1,766
# 794    3,916    3,846    3,673    3,861    3,976    4,121    3,854    3,491
# 901   22,836   20,651   19,834   20,483   23,229   23,356   21,690   19,179
# 910   16,269   16,015   16,806   18,310   21,267   22,347   19,203   16,451
#
#      2020/01  2020/02  2020/03  2020/04  2020/05
# ...
